# %%
from Package.maths import add

# %%
result=add(2,3)
print(result)
# Out:
# 5

# %%
from Package.SUbpackages import multiply
result = multiply(3,4)
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 from Package.SUbpackages import multiply
# ----> 2 result = multiply(3,4)
#       3 print(result)
#
# TypeError: 'module' object is not callable

# %%
import math
print(math.sqrt(16))
# Out:
# 4.0
