# %%
n=4
def square(n):
    result=[]
    for i in range(n):
        result.append(i**2)
    return result

# %%
square(4)
# Out:
# [0, 1, 4, 9]

# %%
def square(n):
    for i in range(3):
        yield i **2

# %%
a=square(3)

# %%
a
# Out:
# <generator object square at 0x00000176CF552B50>

# %%
next(a)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 next(a)
#
# StopIteration:
