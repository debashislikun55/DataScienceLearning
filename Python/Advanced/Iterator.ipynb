# %%
my_list = [1,2,3,4,5]
for i in my_list:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
iterable1=iter(my_list)

# %%
type(iterable1)
# Out:
# list_iterator

# %%
next(iterable1)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 next(iterable1)
#
# StopIteration:

# %%
try:
    print(next(iterable1))
except:
    print("There are no more elements in the list ")
# Out:
# There are no more elements in the list

# %%
my_string = "Hello"
string_iterator = iter(my_string)

# %%
next(string_iterator)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 next(string_iterator)
#
# StopIteration:
