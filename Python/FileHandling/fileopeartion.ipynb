# %%
with open('example.txt' , 'r') as file:
    content=file.read()
    
print(content)
# Out:
# Hello How are you?
# I am good
# Krish is my name
# Welcome to the course

# %%
with open('example.txt','r') as file:
    content=file.read()
print(content)
# Out:
# Hello How are you?
# I am good
# Krish is my name
# Welcome to the course

# %%
#Read file line by line 

with open('example.txt','r') as file:
    for line in file:
        print(line.strip())
# Out:
# Hello How are you?
# I am good
# Krish is my name
# Welcome to the course

# %%
#Writing a file 

#overwriting 

with open('example.txt','w') as file:
    file.write('Hello World\n')
    file.write("This is a new line ")

# %%
#without overwriting 

with open('example.txt','a') as file:
    file.write("\nThis is a new line ")

# %%
#Writing list of lines to file 

lines = ['\nfirst line','\n second line','\n third line ']

with open('example.txt','a') as file:
    file.writelines(lines)

# %%
### Binary Files

# Writing to a binary file

data = b'\x00\x01\x02\x03\x04'
with open('example.bin','wb') as file:
    file.write(data)

# %%
#reading a binary file 

with open('example.bin','rb') as file:
    content = file.read()

# %%
content
# Out:
# b'\x00\x01\x02\x03\x04'

# %%
#copying from one source file to another destination file 

with open('source.txt','r') as file:
    content= file.read()

with open('destination.txt' , 'w') as file:
    file.write(content)

# %%
#Read a text file and count the number of lines, words, and characters.
# Counting lines, words, and characters in a text file

# %%
import os

# %%
cwd=os.getcwd()
cwd
# Out:
# 'd:\\Learnings\\DataScienceLearning\\Python\\FileHandling'

# %%
new_directory="newdir"
os.mkdir(new_directory)

# %%
#listing files and directories 

os.listdir('.')
# Out:
# ['destination.txt',
#  'example.bin',
#  'example.txt',
#  'fileopeartion.ipynb',
#  'newdir',
#  'source.txt']

# %%
path='example1.txt'
if os.path.exists(path):
    print("yes")
else:
    print("NO")
# Out:
# NO

# %%
#Checking if a Path is a File or Directory
import os

path1='example.bin'
if(os.path.isfile(path1)):
    print("file")
elif(os.path.isdir(path)):
    print("dir")
else:
    print("Neither dir not file ")
# Out:
# file

# %%
os.getcwd()
# Out:
# 'd:\\Learnings\\DataScienceLearning\\Python\\FileHandling'

# %%
os.path.abspath('example.bin')
# Out:
# 'd:\\Learnings\\DataScienceLearning\\Python\\FileHandling\\example.bin'

# %%
with open('example2.txt','r') as file:
    content=file.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 with open('example2.txt','r') as file:
#       2     content=file.read()
#
# File d:\Learnings\DataScienceLearning\.venv\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'example2.txt'

# %%
with open('example.txt','r+') as file:
    file.write("Hello\n")

# %%
with open('example.txt','w') as file:
    file.write('How are you?\n')

# %%
with open('example.txt','w+') as file:
    file.write('How\n')
