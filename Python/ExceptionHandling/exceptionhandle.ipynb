# %%
n=int(input("Enter the number"))
try:
    res=10/n
except ZeroDivisionError:
    print("Can not be divided by zero")
else:
    print(f"Division result is {res} ")
finally:
    print("Exceution completed ")
# Out:
# Can not be divided by zero
# Exceution completed

# %%
try:
    a=10
    c=a/b
except ZeroDivisionError as ex:
    print(ex)
    print("Zero can not be divided ")
except Exception as ex:
    print(ex)
    print("Main exception called")
# Out:
# name 'b' is not defined
# Main exception called

# %%
#catching specific exception 
n=int(input("Enter the number"))
try:
    res=10/n
except ZeroDivisionError:
    print("Can not be divided by zero")
# Out:
# Can not be divided by zero

# %%
#catching multiple exception 

try:
    n=int(input("Enter the number"))
    res=10/n
except (ZeroDivisionError,ValueError) as ex:
    print(ex)
    print("Error:", ex)
# Out:
# invalid literal for int() with base 10: 'ji'
# Error: invalid literal for int() with base 10: 'ji'

# %%
class AgeError(Exception):
    pass

def SetAge(Age):
    if(Age<0):
        raise AgeError(f"Age is : {Age}   can not be negative")
    print(f"Age is {Age}")

try:
    SetAge(-5)
except AgeError as ex:
    print(ex)
# Out:
# Age is : -5   can not be negative
