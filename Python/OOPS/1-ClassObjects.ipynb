# %%
class Car:
    pass

car1=Car()

# %%
print(type(car1))
# Out:
# <class '__main__.Car'>

# %%
class Person:
    def __init__(self,name,age):
        self.Age=age # instance variable 
        self.Name=name

    def greet(self):
        return f"Hi, I am {self.Name} and I am {self.Age} years old"
    
person1= Person("Debahis",25)
person1.greet()
# Out:
# 'Hi, I am Debahis and I am 25 years old'

# %%
class Vehicle:
    def __init__(self,brand,price):
        self.brand=brand
        self.price=price

    def cardetails(self):
        print(f"{self.brand} : {self.price}")


audi = Vehicle("Audi",109836363)
audi.cardetails()
# Out:
# Audi : 109836363

# %%
#Instance method and class methods

#Instance nethods 


class Student:
    def __init__(self,name):
        self.name=name

    def greet(self):
        print(f"Hello {self.name}")

Student1= Student("Debashis")

Student2 = Student("Sahoo")

# %%
Student1.greet()
# Out:
# Hello Debashis

# %%
Student2.greet()
# Out:
# Hello Sahoo

# %%
#Class methods 


class Student:
    school = "ABC School"   # class variable

    def __init__(self, name):
        self.name = name

    @classmethod
    def change_school(cls, new_school):
        cls.school = new_school

# %%
s1 = Student("Amit")
s2 = Student("Ravi")

print(s1.school)
print(s2.school)

Student.change_school("XYZ School")

print(s1.school)
print(s2.school)
# Out:
# ABC School
# ABC School
# XYZ School
# XYZ School

# %%
class Employee:
    @staticmethod
    def is_valid_age(age):
        return age>18
