# %%
## Inheritance (Single Inheritance)
## Parent class
class Car:
    def __init__(self,windows,doors,enginetype):
        self.windows=windows
        self.doors=doors
        self.enginetype=enginetype
    
    def drive(self):
        print(f"The person will drive the {self.enginetype} car ")

# %%
class Tesla(Car):
    def __init__(self, windows, doors, enginetype,is_selfdriving):
        super().__init__(windows, doors, enginetype)
        self.is_selfdriving = is_selfdriving

    def Tesladetails(self):
        print(f"{self.enginetype} is {self.is_selfdriving}")

# %%
Tesla1=Tesla(4,4,"Tesla",True)

# %%
Tesla1.drive()
# Out:
# The person will drive the Tesla car

# %%
Tesla1.Tesladetails()
# Out:
# Tesla is True

# %%
#Types of Inheritance

# %%
'''

1- Single Inheritance
2- Multi level inheritance 
3- Multiple inheritance 
4- Heirarchical Inheritance 
5- Hybrid Inheritance 
'''

# %%
#1- Single Inheritance 

class Vehicle:
    def move(self):
        print("Vehicle moves")

class Car(Vehicle):
    pass

# %%
#2- Mutli lebel inheritance 

class A:
    def show_A(self):
        print("A")
class B(A):
    def show_B(self):
        print("B")
class C(B):
    def show_C(self):
        print("C")

# %%
c1 = C()

# %%
c1.show_A()
c1.show_B()
c1.show_C()
# Out:
# A
# B
# C

# %%
#3- Multiple Inheritance 
#2- Mutli lebel inheritance 

class A:
    def show_A(self):
        print("A")
class B:
    def show_B(self):
        print("B")
class C(A):
    def show_D(self):
        print("D")

class D(A,B):
    pass

# %%
D1=D()

# %%
D1.show_A()
# Out:
# A

# %%
D1.show_B()
# Out:
# B

# %%
print(D.mro())
# Out:
# [<class '__main__.D'>, <class '__main__.A'>, <class '__main__.B'>, <class 'object'>]

# %%
#Calling parent method using super keyword 


#2- Mutli lebel inheritance 

class A:
    def show_A(self):
        print("A")
class B(A):
    def show_B(self):
        print("B")
        super().show_A()
class C(B):
    def show_C(self):
        print("C")

# %%
B1=B()

# %%
B1.show_B()
# Out:
# B
# A

# %%
#constructor inheritance 

class Car:
    def __init__(self,brand):
        self.brand=brand 

    
class Tesla(Car):
    def __init__(self, brand,price):
        super().__init__(brand)#constructor inheritanve 
        self.price = price
